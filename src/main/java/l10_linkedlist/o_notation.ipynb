# %% [markdown]
# ## O-notation

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
upper_bound = 5
x = np.arange(1, upper_bound)

plt.figure(figsize= (10, 6), dpi = 200)
plt.title("O-notation")
plt.xlabel("Quantity of data")
plt.ylabel("Number of operations")

plt.xlim(xmin=1, xmax = upper_bound)

plt.grid()

plt.plot(x, np.ones(len(x)) + 5, label="Constant")
# plt.plot(x, np.log(x) , label="Logarithmic")
# plt.plot(x, x, label="Linear")
# plt.plot(x, np.log(x) * x, label="n * log(n)")

# plt.plot(x, x ** 2, label="Quadratic")
# plt.plot(x, x ** 3, label="Cubic")
# plt.plot(x, np.exp2(x), label="Exponential")

plt.legend()

# %% [markdown]
# ## Bokeh

# %%
from bokeh.io import output_file, show, output_notebook, push_notebook
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, HoverTool, CategoricalColorMapper
from bokeh.layouts import row,column,gridplot
from bokeh.models.widgets import Tabs, Panel
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7ace9654-0f6e-416b-b2bb-022d5b6d4d14">Loading BokehJS ...</span>
#     </div>

# %%
plot = figure(x_axis_label = "amount of input", y_axis_label = "number of operations")

x = np.arange(1, 500)
plot.line(x, np.ones(len(x)) + 5, color="blue", legend="Constant")
plot.line(x, np.log(x), color="grey", legend="Logarithmic")

plot.line(x = x, y= x, color= "green", legend="Linear")
plot.line(x, np.log(x) * x, color="yellow",legend="n * log(n)")
# plot.line(x = x, y= x ** 2, color="red", legend="Quadratic")
# plot.line(x, x ** 3, color="magenta", legend="Cubic")
# plot.line(x, np.exp2(x), color="black", legend="Exponential")

plot.legend.click_policy="hide"

show(plot)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="d64e352c-d07b-4653-85d3-55d7e724d92e"></div>
# </div>

# %%
import math
var = 10 ** 100
math.log(var)
# Out:
# 230.25850929940458
